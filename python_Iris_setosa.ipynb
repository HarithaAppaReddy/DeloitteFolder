# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:/Users/hagv/Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.rename(columns={'SepalLengthCm':'SL','SepalWidthCm':'SW','PetalLengthCm':'PL','PetalWidthCm':'PW'})
# Out:
#       Id   SL   SW   PL   PW         Species
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
import numpy as np
iris_setosa=data[data['Species']=='Iris-setosa']
iris_versicolor=data[data['Species']=='Iris-versicolor']
iris_virginica=data[data['Species']=='Iris_verginica']

print(iris_setosa)
print(iris_versicolor)
print(iris_virginica)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
print(np.median(iris_setosa['SepalLengthCm']))
# Out:
# 5.0

# %%
print(np.median(iris_setosa['SepalWidthCm']))
# Out:
# 3.4

# %%
r=np.max(iris_setosa['PetalLengthCm'])-np.min(iris_setosa['PetalLengthCm'])
print(r)
# Out:
# 0.8999999999999999

# %%
print(np.std(iris_setosa['SepalWidthCm']))
# Out:
# 0.37719490982779713

# %%
print(np.var(iris_setosa['PetalLengthCm']))
print(np.var(iris_versicolor['PetalLengthCm']))
print(np.var(iris_virginica['PetalLengthCm']))
# Out:
# 0.02950400000000001
# 0.21640000000000012
# nan

# %%
print(np.percentile(iris_setosa['PetalLengthCm'],25))
print(np.percentile(iris_setosa['PetalLengthCm'],50))
print(np.percentile(iris_setosa['PetalLengthCm'],75))
print(np.percentile(iris_setosa['PetalLengthCm'],100))
# Out:
# 1.4
# 1.5
# 1.5750000000000002
# 1.9
